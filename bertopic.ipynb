# %% [markdown]
# # Topic Modelling Approaches
# The aim here is to use BERTopic to topic model *The Years*: first to try the published text and then see whether I can get ahold of material from the genetic dossier to compare.

# %% [markdown]
# ## Imports and Whatnot

# %%
# import nltk libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# download nltk libraries
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# import BERTopic
from bertopic import BERTopic
from umap import UMAP
# Out:
# [nltk_data] Downloading package punkt to /Users/Joshua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Joshua/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Joshua/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Data Munging (Where does that word come from?)

# %%
# read data
data = "data/years-raw.txt"
with open(data, 'r') as file:
    data = file.read().replace('\n', ' ')

# tokenize data
tokens = word_tokenize(data)

# remove punctuation
tokens = [word for word in tokens if word.isalnum()]

# remove stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# lemmatize tokens
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_tokens)
# Out:
# ['YEARS', '1880', 'uncertain', 'spring', 'weather', 'perpetually', 'changing', 'sent', 'cloud', 'blue', 'purple', 'flying', 'land', 'country', 'farmer', 'looking', 'field', 'apprehensive', 'London', 'umbrella', 'opened', 'shut', 'people', 'looking', 'sky', 'April', 'weather', 'expected', 'Thousands', 'shop', 'assistant', 'made', 'remark', 'handed', 'neat', 'parcel', 'lady', 'flounced', 'dress', 'standing', 'side', 'counter', 'Whiteley', 'Army', 'Navy', 'Stores', 'Interminable', 'procession', 'shopper', 'West', 'end', 'business', 'men', 'East', 'paraded', 'pavement', 'like', 'caravan', 'perpetually', 'marching', 'seemed', 'reason', 'pause', 'say', 'post', 'letter', 'club', 'window', 'Piccadilly', 'stream', 'landau', 'victoria', 'hansom', 'cab', 'incessant', 'season', 'beginning', 'quieter', 'street', 'musician', 'doled', 'frail', 'part', 'melancholy', 'pipe', 'sound', 'echoed', 'parodied', 'tree', 'Hyde', 'Park', 'James', 'twitter', 'sparrow', 'sudden', 'outburst', 'amorous', 'intermittent', 'thrush', 'pigeon', 'square', 'shuffled', 'tree', 'top', 'letting', 'fall', 'twig', 'two', 'crooned', 'lullaby', 'always', 'interrupted', 'gate', 'Marble', 'Arch', 'Apsley', 'House', 'blocked', 'afternoon', 'lady', 'dress', 'wearing', 'bustle', 'gentleman', 'frock', 'coat', 'carrying', 'cane', 'wearing', 'carnation', 'came', 'Princess', 'passed', 'hat', 'lifted', 'basement', 'long', 'avenue', 'residential', 'quarter', 'servant', 'girl', 'cap', 'apron', 'prepared', 'tea', 'Deviously', 'ascending', 'basement', 'silver', 'teapot', 'placed', 'table', 'virgin', 'spinster', 'hand', 'staunched', 'sore', 'Bermondsey', 'Hoxton', 'carefully', 'measured', 'one', 'two', 'three', 'four', 'spoonful', 'tea', 'sun', 'went', 'million', 'little', 'gaslight', 'shaped', 'like', 'eye', 'peacock', 'feather', 'opened', 'glass', 'cage', 'nevertheless', 'broad', 'stretch', 'darkness', 'left', 'pavement', 'mixed', 'light', 'lamp', 'setting', 'sun', 'reflected', 'equally', 'placid', 'water', 'Round', 'Pond', 'Serpentine', 'trotting', 'Bridge', 'hansom', 'cab', 'looked', 'moment', 'charming', 'vista', 'length', 'moon', 'rose', 'polished', 'coin', 'though', 'obscured', 'wisp', 'cloud', 'shone', 'serenity', 'severity', 'perhaps', 'complete', 'indifference', 'Slowly', 'wheeling', 'like', 'ray', 'searchlight', 'day', 'week', 'year', 'passed', 'one', 'another', 'across', 'sky', 'Colonel', 'Abel', 'Pargiter', 'sitting', 'luncheon', 'club', 'talking', 'Since', 'companion', 'leather', 'armchair', 'men', 'type', 'men', 'soldier', 'civil', 'servant', 'men', 'retired', 'reviving', 'old', 'joke', 'story', 'past', 'India', 'Africa', 'Egypt', 'natural', 'transition', 'turned', 'present', 'question', 'appointment', 'possible', 'appointment', 'Suddenly', 'youngest', 'sprucest', 'three', 'leant', 'forward', 'Yesterday', 'lunched', 'voice', 'speaker', 'fell', 'others', 'bent', 'towards', 'brief', 'wave', 'hand', 'Colonel', 'Abel', 'dismissed', 'servant', 'removing', 'coffee', 'cup', 'three', 'baldish', 'greyish', 'head', 'remained', 'close', 'together', 'minute', 'Colonel', 'Abel', 'threw', 'back', 'chair', 'curious', 'gleam', 'come', 'eye', 'Major', 'Elkin', 'began', 'story', 'faded', 'completely', 'Colonel', 'Pargiter', 'face', 'sat', 'staring', 'ahead', 'bright', 'blue', 'eye', 'seemed', 'little', 'screwed', 'glare', 'East', 'still', 'puckered', 'corner', 'dust', 'still', 'thought', 'struck', 'made', 'others', 'saying', 'interest', 'indeed', 'disagreeable', 'rose', 'looked', 'window', 'Piccadilly', 'Holding', 'cigar', 'suspended', 'looked', 'top', 'omnibus', 'hansom', 'cab', 'victoria', 'van', 'landau', 'attitude', 'seemed', 'say', 'longer', 'finger', 'pie', 'Gloom', 'settled', 'red', 'handsome', 'face', 'stood', 'gazing', 'Suddenly', 'thought', 'struck', 'question', 'ask', 'turned', 'ask', 'friend', 'gone', 'little', 'group', 'broken', 'Elkins', 'already', 'hurrying', 'door', 'Brand', 'moved', 'talk', 'another', 'man', 'Colonel', 'Pargiter', 'shut', 'mouth', 'thing', 'might', 'said ...

# %% [markdown]
# ## BERTopic implies an ERNIETopic, in this essay I will,,,

# %% [markdown]
# ### Generating topic model

# %%
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(lemmatized_tokens)
topic_model.save("model")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-06-15 23:09:52,656 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %% [markdown]
# ### Visualising data

# %%
topic_model = BERTopic.load("model")

topic_model.get_topic_info()
# Out:
#       Topic  Count                                   Name  \
# 0        -1   2198         -1_spotted_habit_victoria_form
# 1         0   1724                        0_said_stated__
# 2         1    475                            1_looked___
# 3         2    449                           2_thought___
# 4         3    437                    3_eleanor_mildred__
# ...     ...    ...                                    ...
# 1458   1457     10           1457_crossing_crisscrossed__
# 1459   1458     10                      1458_litter_cat__
# 1460   1459     10           1459_mend_mended_wedd_loosed
# 1461   1460     10                        1460_eleanor___
# 1462   1461     10  1461_gainsborough_pont_norfolk_sussex
#
#                                          Representation  \
# 0     [spotted, habit, victoria, form, pencil, dazed...
# 1                        [said, stated, , , , , , , , ]
# 2                            [looked, , , , , , , , , ]
# 3                           [thought, , , , , , , , , ]
# 4                    [eleanor, mildred, , , , , , , , ]
# ...                                                 ...
# 1458           [crossing, crisscrossed, , , , , , , , ]
# 1459                      [litter, cat, , , , , , , , ]
# 1460  [mend, mended, wedd, loosed, dandy, shepherded...
# 1461                        [eleanor, , , , , , , , , ]
# 1462  [gainsborough, pont, norfolk, sussex, bordeaux...
#
#                              Representative_Docs
# 0                      [spotted, spotted, habit]
# 1                             [said, said, said]
# 2                       [looked, looked, looked]
# 3                    [thought, thought, thought]
# 4                    [Eleanor, Eleanor, Eleanor]
# ...                                          ...
# 1458              [crossing, crossing, crossing]
# 1459                    [litter, litter, litter]
# 1460                          [mend, mend, mend]
# 1461                 [Eleanor, Eleanor, Eleanor]
# 1462  [Gainsborough, Gainsborough, Gainsborough]
#
# [1463 rows x 5 columns]
