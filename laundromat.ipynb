# %% [markdown]
# # Years Data Laundromat
#
# This cleans and lemmatizes the raw .txt files for each chapter of *The Years*.

# %% [markdown]
# ### Imports and Whatnot

# %%
import sys
import os
from pprint import pprint as pp
import string

# import nltk
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import nbformat

# %% [markdown]
# ### Setting up corpus and cleaning data

# %%
corpus = [
  'data/1880.txt',
  'data/1891.txt',
  'data/1907.txt',
  'data/1908.txt',
  'data/1910.txt',
  'data/1911.txt',
  'data/1913.txt',
  'data/1914.txt',
  'data/1917.txt',
  'data/1918.txt',
  'data/present.txt'
]

lemmatized_corpus = [
  'data/1880_lemmatized.txt',
  'data/1891_lemmatized.txt',
  'data/1907_lemmatized.txt',
  'data/1908_lemmatized.txt',
  'data/1910_lemmatized.txt',
  'data/1911_lemmatized.txt',
  'data/1913_lemmatized.txt',
  'data/1914_lemmatized.txt',
  'data/1917_lemmatized.txt',
  'data/1918_lemmatized.txt',
  'data/present_lemmatized.txt'
]

# setting nltk resources and stopwords
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
default_stopwords_set = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# removing stopwords and punctuation
extended_punctuation = set(string.punctuation) | {'“', '”', '’', '‘', '—', '…', '\'', '`'}

def remove_stopwords(words):
  return [word for word in words if not word.lower() in default_stopwords_set]

def remove_punctuation(words):
    return [word for word in words if word not in string.punctuation]

# lemmatizing each file in corpus

for i in corpus:
  with open(i, 'r') as f:
    file = f.read()

    # tokenizing each file into words and removing stopwords
    words = word_tokenize(file)
    words = remove_stopwords(words)
    words = remove_punctuation(words)

    # lemmatizing each word individually
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

    # joining the lemmatized words back into a string
    lemmatized_file = ' '.join(lemmatized_words)

    # writing the lemmatized file to new files
    with open(i.replace('.txt', '_lemmatized.txt'), 'w') as f:
      f.write(lemmatized_file)

# creating a dictionary of words from the lemmatized corpus
word_dictionary = []

for file_path in lemmatized_corpus:
  with open(file_path, 'r') as f:
    file_content = f.read()
    word_dictionary.append(word_tokenize(file_content))
print(word_dictionary)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joshua/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/joshua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/joshua/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/joshua/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [['1880', 'uncertain', 'spring', 'weather', 'perpetually', 'changing', 'sent', 'cloud', 'blue', 'purple', 'flying', 'land', 'country', 'farmer', 'looking', 'field', 'apprehensive', 'London', 'umbrella', 'opened', 'shut', 'people', 'looking', 'sky', 'April', 'weather', 'expected', 'Thousands', 'shop', 'assistant', 'made', 'remark', 'handed', 'neat', 'parcel', 'lady', 'flounced', 'dress', 'standing', 'side', 'counter', 'Whiteley', "'s", 'Army', 'Navy', 'Stores', 'Interminable', 'procession', 'shopper', 'West', 'end', 'business', 'men', 'East', 'paraded', 'pavement', 'like', 'caravan', 'perpetually', 'marching', '--', 'seemed', 'reason', 'pause', 'say', 'post', 'letter', 'club', 'window', 'Piccadilly', 'stream', 'landau', 'victoria', 'hansom', 'cab', 'incessant', 'season', 'beginning', 'quieter', 'street', 'musician', 'doled', 'frail', 'part', 'melancholy', 'pipe', 'sound', 'echoed', 'parodied', 'tree', 'Hyde', 'Park', 'St.', 'James', "'s", 'twitter', 'sparrow', 'sudden', 'outburst', 'amorous', 'intermittent', 'thrush', 'pigeon', 'square', 'shuffled', 'tree', 'top', 'letting', 'fall', 'twig', 'two', 'crooned', 'lullaby', 'always', 'interrupted', 'gate', 'Marble', 'Arch', 'Apsley', 'House', 'blocked', 'afternoon', 'lady', 'many-coloured', 'dress', 'wearing', 'bustle', 'gentleman', 'frock', 'coat', 'carrying', 'cane', 'wearing', 'carnation', 'came', 'Princess', 'passed', 'hat', 'lifted', 'basement', 'long', 'avenue', 'residential', 'quarter', 'servant', 'girl', 'cap', 'apron', 'prepared', 'tea', 'Deviously', 'ascending', 'basement', 'silver', 'teapot', 'placed', 'table', 'virgin', 'spinster', 'hand', 'staunched', 'sore', 'Bermondsey', 'Hoxton', 'carefully', 'measured', 'one', 'two', 'three', 'four', 'spoonful', 'tea', 'sun', 'went', 'million', 'little', 'gaslight', 'shaped', 'like', 'eye', 'peacock', 'feather', 'opened', 'glass', 'cage', 'nevertheless', 'broad', 'stretch', 'darkness', 'left', 'pavement', 'mixed', 'light', 'lamp', 'setting', 'sun', 'reflected', 'equally', 'placid', 'water', 'Round', 'Pond', 'Serpentine', 'Diners-out', 'trotting', 'Bridge', 'hansom', 'cab', 'looked', 'moment', 'charming', 'vista', 'length', 'moon', 'rose', 'polished', 'coin', 'though', 'obscured', 'wisp', 'cloud', 'shone', 'serenity', 'severity', 'perhaps', 'complete', 'indifference', 'Slowly', 'wheeling', 'like', 'ray', 'searchlight', 'day', 'week', 'year', 'passed', 'one', 'another', 'across', 'sky', 'Colonel', 'Abel', 'Pargiter', 'sitting', 'luncheon', 'club', 'talking', 'Since', 'companion', 'leather', 'armchair', 'men', 'type', 'men', 'soldier', 'civil', 'servant', 'men', 'retired', 'reviving', 'old', 'joke', 'story', 'past', 'India', 'Africa', 'Egypt', 'natural', 'transition', 'turned', 'present', 'question', 'appointment', 'possible', 'appointment', 'Suddenly', 'youngest', 'sprucest', 'three', 'leant', 'forward', 'Yesterday', 'lunched', 'voice', 'speaker', 'fell', 'others', 'bent', 'towards', 'brief', 'wave', 'hand', 'Colonel', 'Abel', 'dismissed', 'servant', 'removing', 'coffee', 'cup', 'three', 'baldish', 'greyish', 'head', 'remained', 'close', 'together', 'minute', 'Colonel', 'Abel', 'threw', 'back', 'chair', 'curious', 'gleam', 'come', 'eye', 'Major', 'Elkin', 'began', 'story', 'faded', 'completely', 'Colonel', 'Pargiter', "'s", 'face', 'sat', 'staring', 'ahead', 'bright', 'blue', 'eye', 'seemed', 'little', 'screwed', 'glare', 'East', 'still', 'puckered', 'corner', 'dust', 'still', 'thought', 'struck', 'made', 'others', 'saying', 'interest', 'indeed', 'disagreeable', 'rose', 'looked', 'window', 'Piccadilly', 'Holding', 'cigar', 'suspended', 'looked', 'top', 'omnibus', 'hansom', 'cab', 'victoria', 'van', 'landau', 'attitude', 'seemed', 'say', 'longer', 'finger', 'pie', 'Gloom', 'settled', 'red', 'handsome', 'face', 'stood', 'gazing', 'Suddenly', 'thought', 'struck', 'question', 'ask', 'turned', 'ask', 'friend', 'gone', 'little', 'group', 'broken', 'Elkins', 'already', 'hurrying', 'door', 'Brand', 'moved', 'talk', 'another', 'man', 'Colonel' ...
